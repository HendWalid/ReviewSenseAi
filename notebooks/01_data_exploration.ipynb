# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (4.8.5)
# Requirement already satisfied: filelock in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (3.29.0)
# Requirement already satisfied: numpy>=1.17 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (2.4.4)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (3.0.2)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (2.33.1)
# Requirement already satisfied: httpx<1.0.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (1.14.0)
# Requirement already satisfied: packaging in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpx<1.0.0->datasets) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpx<1.0.0->datasets) (3.13)
# Requirement already satisfied: h11>=0.16 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.0)
# Requirement already satisfied: typer>=0.20.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from requests>=2.32.2->datasets) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MOHAMED\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\MOHAMED\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\MOHAMED\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\MOHAMED\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\MOHAMED\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# !pip install pandas datasets scikit-learn nltk
# Out:
# Requirement already satisfied: pandas in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (3.0.2)
# Requirement already satisfied: datasets in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (4.8.5)
# Requirement already satisfied: scikit-learn in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (1.8.0)
# Requirement already satisfied: nltk in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (3.9.4)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: filelock in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (3.29.0)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (2.33.1)
# Requirement already satisfied: httpx<1.0.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (4.67.3)
# Requirement already satisfied: xxhash in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (1.14.0)
# Requirement already satisfied: packaging in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpx<1.0.0->datasets) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpx<1.0.0->datasets) (3.13)
# Requirement already satisfied: h11>=0.16 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.0)
# Requirement already satisfied: typer>=0.20.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from nltk) (8.3.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: six>=1.5 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from requests>=2.32.2->datasets) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0,>=0.25.0->datasets) (0.1.2)

# %%
# Load libraries

from datasets import load_dataset
from sklearn.feature_extraction.text import TfidfVectorizer

# import cleaning function
import os
sys.path.append(os.path.abspath('../'))
from src.preprocessing.clean_text import clean_text


from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# =========================================================
# ReviewSense AI - IMDb Data Exploration & Preprocessing
# =========================================================

# Load libraries
import pandas as pd

from datasets import load_dataset

from sklearn.feature_extraction.text import TfidfVectorizer

from src.preprocessing.clean_text import clean_text
# import cleaning function


# =========================
# Load IMDb Dataset
# =========================
dataset = load_dataset("imdb")

print(dataset)


# =========================
# Convert to DataFrames
# =========================
train_df = pd.DataFrame(dataset["train"])
test_df = pd.DataFrame(dataset["test"])


# =========================
# Display Sample
# =========================
print(train_df.head())

print("\nFirst Review:\n")
print(dataset["train"][0])


# =========================
# Apply Text Cleaning
# =========================
print("\nCleaning reviews...")

train_df["clean_review"] = train_df["text"].apply(clean_text)

test_df["clean_review"] = test_df["text"].apply(clean_text)


# =========================
# TF-IDF Feature Extraction
# =========================
print("\nExtracting TF-IDF features...")

vectorizer = TfidfVectorizer(max_features=5000)

X_train = vectorizer.fit_transform(train_df["clean_review"])

X_test = vectorizer.transform(test_df["clean_review"])


# =========================
# Labels
# =========================
y_train = train_df["label"]

y_test = test_df["label"]


# =========================
# Shapes
# =========================
print("\nTrain Features Shape:", X_train.shape)
print("Test Features Shape:", X_test.shape)

print("\nTrain Labels Shape:", y_train.shape)
print("Test Labels Shape:", y_test.shape)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     unsupervised: Dataset({
#         features: ['text', 'label'],
#         num_rows: 50000
#     })
# })
#                                                 text  label
# 0  I rented I AM CURIOUS-YELLOW from my video sto...      0
# 1  "I Am Curious: Yellow" is a risible and preten...      0
# 2  If only to avoid making this type of film in t...      0
# 3  This film was probably inspired by Godard's Ma...      0
# 4  Oh, brother...after hearing about this ridicul...      0
#
# First Review:
#
# {'text': 'I rented I AM CURIOUS-YELLOW from my video store because of all the controversy that surrounded it when it was first released in 1967. I also heard that at first it was seized by U.S. customs if it ever tried to enter this country, therefore being a fan of films considered "controversial" I really had to see this for myself.<br /><br />The plot is centered around a young Swedish drama student named Lena who wants to learn everything she can about life. In particular she wants to focus her attentions to making some sort of documentary on what the average Swede thought about certain political issues such as the Vietnam War and race issues in the United States. In between asking politicians and ordinary denizens of Stockholm about their opinions on politics, she has sex with her drama teacher, classmates, and married men.<br /><br />What kills me about I AM CURIOUS-YELLOW is that 40 years ago, this was considered pornographic. Really, the sex and nudity scenes are few and far between, even then it\'s not shot like some cheaply made porno. While my countrymen mind find it shocking, in reality sex and nudity are a major staple in Swedish cinema. Even Ingmar Bergman, arguably their answer to good old boy John Ford, had sex scenes in his films.<br /><br />I do commend the filmmakers for the fact that any sex shown in the film is shown for artistic purposes rather than just to shock people and make money to be shown in pornographic theaters in America. I AM CURIOUS-YELLOW is a good film for anyone wanting to study the meat and potatoes (no pun intended) of Swedish cinema. But really, this film doesn\'t have much of a plot.', 'label': 0}
#
# Cleaning reviews...
#
# Extracting TF-IDF features...
#
# Train Features Shape: (25000, 5000)
# Test Features Shape: (25000, 5000)
#
# Train Labels Shape: (25000,)
# Test Labels Shape: (25000,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 80
#      76 print("\nTrain Labels Shape:", y_train.shape)
#      77 print("Test Labels Shape:", y_test.shape)
#      78
#      79
# ---> 80 df_train["text"][0]
#
# NameError: name 'df_train' is not defined

# %%
print(train_df["clean_review"][0])
# Out:
# rented curiousyellow video store controversy surrounded first released also heard first seized custom ever tried enter country therefore fan film considered controversial really see myselfthe plot centered around young swedish drama student named lena want learn everything life particular want focus attention making sort documentary average swede thought certain political issue vietnam war race issue united state asking politician ordinary denizen stockholm opinion politics sex drama teacher classmate married menwhat kill curiousyellow year ago considered pornographic really sex nudity scene far even shot like cheaply made porno countryman mind find shocking reality sex nudity major staple swedish cinema even ingmar bergman arguably answer good old boy john ford sex scene filmsi commend filmmaker fact sex shown film shown artistic purpose rather shock people make money shown pornographic theater america curiousyellow good film anyone wanting study meat potato pun intended swedish cinema really film doesnt much plot

# %%
print(train_df["clean_review"].isnull().sum())
print(test_df["clean_review"].isnull().sum())
# Out:
# 0
# 0

# %%
print((train_df["clean_review"] == "").sum())
print((test_df["clean_review"] == "").sum())
# Out:
# 0
# 0

# %%
print("BEFORE:\n", train_df["text"][0])
print("\nAFTER:\n", train_df["clean_review"][0])
# Out:
# BEFORE:
#  I rented I AM CURIOUS-YELLOW from my video store because of all the controversy that surrounded it when it was first released in 1967. I also heard that at first it was seized by U.S. customs if it ever tried to enter this country, therefore being a fan of films considered "controversial" I really had to see this for myself.<br /><br />The plot is centered around a young Swedish drama student named Lena who wants to learn everything she can about life. In particular she wants to focus her attentions to making some sort of documentary on what the average Swede thought about certain political issues such as the Vietnam War and race issues in the United States. In between asking politicians and ordinary denizens of Stockholm about their opinions on politics, she has sex with her drama teacher, classmates, and married men.<br /><br />What kills me about I AM CURIOUS-YELLOW is that 40 years ago, this was considered pornographic. Really, the sex and nudity scenes are few and far between, even then it's not shot like some cheaply made porno. While my countrymen mind find it shocking, in reality sex and nudity are a major staple in Swedish cinema. Even Ingmar Bergman, arguably their answer to good old boy John Ford, had sex scenes in his films.<br /><br />I do commend the filmmakers for the fact that any sex shown in the film is shown for artistic purposes rather than just to shock people and make money to be shown in pornographic theaters in America. I AM CURIOUS-YELLOW is a good film for anyone wanting to study the meat and potatoes (no pun intended) of Swedish cinema. But really, this film doesn't have much of a plot.
#
# AFTER:
#  rented curiousyellow video store controversy surrounded first released also heard first seized custom ever tried enter country therefore fan film considered controversial really see myselfthe plot centered around young swedish drama student named lena want learn everything life particular want focus attention making sort documentary average swede thought certain political issue vietnam war race issue united state asking politician ordinary denizen stockholm opinion politics sex drama teacher classmate married menwhat kill curiousyellow year ago considered pornographic really sex nudity scene far even shot like cheaply made porno countryman mind find shocking reality sex nudity major staple swedish cinema even ingmar bergman arguably answer good old boy john ford sex scene filmsi commend filmmaker fact sex shown film shown artistic purpose rather shock people make money shown pornographic theater america curiousyellow good film anyone wanting study meat potato pun intended swedish cinema really film doesnt much plot

# %%
train_df.to_csv('../data/processed/train_cleaned.csv', index=False)
test_df.to_csv('../data/processed/test_cleaned.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 train_df.to_csv('../data/processed/train_cleaned.csv', index=False)
#       2 test_df.to_csv('../data/processed/test_cleaned.csv', index=False)
#
# File c:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3984             float_format=float_format,
#    3985             decimal=decimal,
#    3986         )
#    3987
# -> 3988         return DataFrameRenderer(formatter).to_csv(
#    3989             path_or_buf,
#    3990             lineterminator=lineterminator,
#    3991             sep=sep,
#
# File c:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages\pandas\io\formats\format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
#     272     self._save()
#
# File c:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages\pandas\io\common.py:793, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     791 # Only for write methods
#     792 if "r" not in mode and is_path:
# --> 793     check_parent_directory(str(handle))
#     795 if compression:
#     796     if compression != "zstd":
#     797         # compression libraries do not like an explicit text-mode
#
# File c:\Users\MOHAMED\Desktop\ReviewSenseAi\venv\Lib\site-packages\pandas\io\common.py:652, in check_parent_directory(path)
#     650 parent = Path(path).parent
#     651 if not parent.is_dir():
# --> 652     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..\data\processed'
