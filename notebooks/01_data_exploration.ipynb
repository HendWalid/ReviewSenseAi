# %%
# !pip install datasets
# Out:
# ...
#      -------------------------------------- 529.0/529.0 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached filelock-3.29.0-py3-none-any.whl (39 kB)
# ...
#   Using cached numpy-2.4.4-cp311-cp311-win_amd64.whl (12.6 MB)
# ...
#      ---------------------------------------- 27.3/27.3 MB 2.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 120.0/120.0 kB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.9/9.9 MB 2.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 73.0/73.0 kB 1.4 MB/s eta 0:00:00
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# ...
#   Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# ...
#      -------------------------------------- 144.5/144.5 kB 2.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 202.5/202.5 kB 2.1 MB/s eta 0:00:00
# ...
#   Using cached huggingface_hub-1.14.0-py3-none-any.whl (661 kB)
# ...
#   Using cached packaging-26.2-py3-none-any.whl (100 kB)
# ...
#   Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
# ...

# %%
# !pip install pandas datasets scikit-learn nltk
# Out:
# ...
#      ---------------------------------------- 8.1/8.1 MB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.6/1.6 MB 3.7 MB/s eta 0:00:00
# ...
#   Using cached scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
# ...
#      -------------------------------------- 309.1/309.1 kB 3.2 MB/s eta 0:00:00
# ...
#   Using cached regex-2026.5.9-cp311-cp311-win_amd64.whl (278 kB)
# ...
# [notice] A new release of pip available: 22.3 -> 26.1.1
# [notice] To update, run: C:\Users\pc\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# Load libraries
# Load libraries
import pandas as pd

from datasets import load_dataset
from sklearn.feature_extraction.text import TfidfVectorizer

# import cleaning function
import sys
sys.path.append(r"C:\Users\pc\Desktop\ReviewSenseAi\src")
from preprocessing.clean_text import clean_text

from datasets import load_dataset

from sklearn.feature_extraction.text import TfidfVectorizer

# import cleaning function
import sys
sys.path.append(r"C:\Users\pc\Desktop\ReviewSenseAi\src\preprocessing")

from preprocessing.clean_text import clean_text
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Load libraries
# ----> 2 import pandas as pd
#       3
#       4 from datasets import load_dataset
#       5
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# =========================================================
# ReviewSense AI - IMDb Data Exploration & Preprocessing
# =========================================================

# Load libraries
import pandas as pd

from datasets import load_dataset

from sklearn.feature_extraction.text import TfidfVectorizer

# import cleaning function
from preprocessing.clean_text import clean_text


# =========================
# Load IMDb Dataset
# =========================
dataset = load_dataset("imdb")

print(dataset)


# =========================
# Convert to DataFrames
# =========================
train_df = pd.DataFrame(dataset["train"])
test_df = pd.DataFrame(dataset["test"])


# =========================
# Display Sample
# =========================
print(train_df.head())

print("\nFirst Review:\n")
print(dataset["train"][0])


# =========================
# Apply Text Cleaning
# =========================
print("\nCleaning reviews...")

train_df["clean_review"] = train_df["text"].apply(clean_text)

test_df["clean_review"] = test_df["text"].apply(clean_text)


# =========================
# TF-IDF Feature Extraction
# =========================
print("\nExtracting TF-IDF features...")

vectorizer = TfidfVectorizer(max_features=5000)

X_train = vectorizer.fit_transform(train_df["clean_review"])

X_test = vectorizer.transform(test_df["clean_review"])


# =========================
# Labels
# =========================
y_train = train_df["label"]

y_test = test_df["label"]


# =========================
# Shapes
# =========================
print("\nTrain Features Shape:", X_train.shape)
print("Test Features Shape:", X_test.shape)

print("\nTrain Labels Shape:", y_train.shape)
print("Test Labels Shape:", y_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 6
#       2 # ReviewSense AI - IMDb Data Exploration & Preprocessing
#       3 # =========================================================
#       4
#       5 # Load libraries
# ----> 6 import pandas as pd
#       7
#       8 from datasets import load_dataset
#       9
#
# ModuleNotFoundError: No module named 'pandas'
